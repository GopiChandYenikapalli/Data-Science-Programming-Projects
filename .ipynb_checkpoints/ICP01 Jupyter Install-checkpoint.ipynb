# %% [markdown]
# # ICP01 Jupyter Install
# ## Gopi Chand Yenikapalli

# %% [markdown]
# ![Gopi%20Linkedin.jpeg](attachment:Gopi%20Linkedin.jpeg)
#
# Wherever you go DATA comes to you or DATA comes from you.
#
# I envision myself as an influencer Data Scientist/ Data Analyst to deliver valuable insights from data where I can utilize my technical and managerial skills to permute business decisions and guide organizations towards great efficiency.
#
# I worked as an Assistant Manager and Subject Matter Expert-Oracle Functional role Mumbai, India
#  ∗ Implemented Oracle Enterprise Resource Planning for facility maintenance modules at 18 locations in India, master data management, big data analytics, data engineering, business transformation, business analytics, process change management documentation, asset accounting mapping, coordination with facility users.
# ∗ Led team of 4 maintenance engineers, managing schedules, performance reviews and daily tasks
# ∗ With Deloitte as our systems integration partner and Ernst Young as our data cleansing and project monitoring partner, we have trained 150 facility users on Oracle system integration testing, user acceptance testing, and end user testing.
#
# After completing my Bachelor's degree from the National Institute of technology, Raipur, India. I wanted to explore data from the lens of industry. During my job, I gained very good experience in how analytics work on the real-life dataset. My curiosity and interests kept on increasing day by day. I wanted to learn even more in this field, so I decided to pursue masters in the same (Business analytics and information's systems)
#
# Currently, I am a Master's student in the domain of Business Analytics and Information Science with a major in Data Analytics from the University of South Florida in Tampa, USA. I am specializing in Data Mining, Advanced Database Management, Machine Learning, Data Science Programming, Data Visualization, Analytical Methods for Business, Project Management, Artificial Intelligence and Big Data.
#
# I am an Engineer who is back to school :)
#
# Technical Skill Set:
# Languages/ Software: Python, C, SQL, Advanced Excel, R,MATLAB, Microsoft Project, Oracle, Tableau
# Analytical Expertise: Data Manipulation, Data Visualization, Data Analytics.

# %%
print("Hello World")
# Out:
# Hello World
