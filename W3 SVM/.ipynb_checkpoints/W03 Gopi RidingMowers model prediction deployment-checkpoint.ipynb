# %% [markdown]
# # The RidingMowers Ownership Prediction

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

import pickle

def convert(x):
    if x == 1:
        return('Owner')
    else:
        return('Nonowner')
'''As we encoded target variables using label encoding, when we need to display Owner or Nonowner in the predicted model,
I defined above function to easy access'''

# Uncomment the following snippet of code to debug problems with finding the .pkl file path
# This snippet of code will exit the program and print the current working directory.
#import os
#exit(os.getcwd())

# load the pre-trained SVM model
RidingMowers_model = pickle.load(open('SVM_Linear_model_1.pkl', 'rb'))

print("\n*****************************************************")
print("* The RidingMowers Ownership Prediction *")
print("*****************************************************\n")

# use a while loop to repeatedly ask for inputs and generate predictions
while True:
    # ask for inputs from the user
    Income = float(input("Enter the Income: "))
    Lot_Size = float(input("Enter the Lot_size: "))

    # create a pandas dataframe from the input values
    df = pd.DataFrame({'Income': [Income],'Lot_Size': [Lot_Size]})

    # generate a prediction for the input dataframe
    result = RidingMowers_model.predict(df)
    label = convert(result[0])

    # print the input values and predicted label
    print(f"\nThe Income is {Income}$ and Lot_Size is {Lot_Size}, therefore it's indicated that He/She should {label} of a lawnmower\n")

    # ask the user if they want to make another prediction
    choice = input("Do you want to make another prediction? (y/n): ")
    if choice.lower() == 'n':
        break
# Out:
# *****************************************************
# * The RidingMowers Ownership Prediction *
# *****************************************************
#
# Enter the Income: 90
# Enter the Lot_size: 15
#
# The Income is 90.0$ and Lot_Size is 15.0, therefore it's indicated that He/She should Owner of a lawnmower
#
# Do you want to make another prediction? (y/n): y
# Enter the Income: 110
# Enter the Lot_size: 18
#
# The Income is 110.0$ and Lot_Size is 18.0, therefore it's indicated that He/She should Owner of a lawnmower
#
# Do you want to make another prediction? (y/n): y
# Enter the Income: 86.6
# Enter the Lot_size: 17
#
# The Income is 86.6$ and Lot_Size is 17.0, therefore it's indicated that He/She should Owner of a lawnmower
#
# Do you want to make another prediction? (y/n): y
# Enter the Income: 72
# Enter the Lot_size: 18
#
# The Income is 72.0$ and Lot_Size is 18.0, therefore it's indicated that He/She should Owner of a lawnmower
#
# Do you want to make another prediction? (y/n): y
# Enter the Income: 68
# Enter the Lot_size: 14
#
# The Income is 68.0$ and Lot_Size is 14.0, therefore it's indicated that He/She should Nonowner of a lawnmower
#
# Do you want to make another prediction? (y/n): y
# Enter the Income: 88
# Enter the Lot_size: 20
#
# The Income is 88.0$ and Lot_Size is 20.0, therefore it's indicated that He/She should Owner of a lawnmower
#
# Do you want to make another prediction? (y/n): y
# Enter the Income: 125
# Enter the Lot_size: 42
#
# The Income is 125.0$ and Lot_Size is 42.0, therefore it's indicated that He/She should Owner of a lawnmower
#
# Do you want to make another prediction? (y/n): y
# Enter the Income: 76
# Enter the Lot_size: 14
#
# The Income is 76.0$ and Lot_Size is 14.0, therefore it's indicated that He/She should Nonowner of a lawnmower
#
# Do you want to make another prediction? (y/n): y
# Enter the Income: 68
# Enter the Lot_size: 5
#
# The Income is 68.0$ and Lot_Size is 5.0, therefore it's indicated that He/She should Nonowner of a lawnmower
#
# Do you want to make another prediction? (y/n): y
# Enter the Income: 42
# Enter the Lot_size: 3
#
# The Income is 42.0$ and Lot_Size is 3.0, therefore it's indicated that He/She should Nonowner of a lawnmower
#
# Do you want to make another prediction? (y/n): y
# Enter the Income: 98
# Enter the Lot_size: 15
#
# The Income is 98.0$ and Lot_Size is 15.0, therefore it's indicated that He/She should Owner of a lawnmower
#
# Do you want to make another prediction? (y/n): y
# Enter the Income: 88
# Enter the Lot_size: 7
#
# The Income is 88.0$ and Lot_Size is 7.0, therefore it's indicated that He/She should Nonowner of a lawnmower
#
# Do you want to make another prediction? (y/n): n
